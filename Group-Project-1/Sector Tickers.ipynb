# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# %matplotlib inline
import pandas as pd
import numpy as np

# %%
import datetime

# %%
# Load the first file of eleven downloaded from Yahoo Finance - (Remember to Change These)
XLB_pd = "Resources/XLB.csv"

# Read file and store into Pandas data frame
XLB = pd.read_csv(XLB_pd)
# Add a column with the ticker symbol
XLB['Ticker'] = 'XLB'

XLB.head()
# Out:
#        Date       Open       High        Low      Close  Adj Close   Volume  \
# 0  1/3/2000  26.671881  26.687500  25.937500  25.968750  16.565908   140500
# 1  1/4/2000  26.000000  26.046881  25.609381  25.718750  16.406433   258000
# 2  1/5/2000  26.015619  26.812500  25.750000  26.781250  17.084217   102700
# 3  1/6/2000  26.796881  27.734381  26.781250  27.468750  17.522791  1335000
# 4  1/7/2000  27.750000  27.937500  27.453119  27.453119  17.512810   620100
#
#   Ticker
# 0    XLB
# 1    XLB
# 2    XLB
# 3    XLB
# 4    XLB

# %%
# Load the second file of eleven downloaded from Yahoo Finance - (Remember to Change These)
XLC_pd = "Resources/XLC.csv"

# Read file and store into Pandas data frame
XLC = pd.read_csv(XLC_pd)
# Add a column with the ticker symbol
XLC['Ticker'] = 'XLC'

XLC.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close   Volume  \
# 0  2018-06-19  49.700001  50.060001  49.580002  49.959999  49.457355    16600
# 1  2018-06-20  50.450001  50.889000  50.450001  50.580002  50.071121   190000
# 2  2018-06-21  50.770000  50.849998  50.200001  50.270000  49.764236   428700
# 3  2018-06-22  50.590000  50.610001  50.189999  50.490002  49.982029   181500
# 4  2018-06-25  50.230000  50.230000  49.014999  49.450001  48.952496  2509600
#
#   Ticker
# 0    XLC
# 1    XLC
# 2    XLC
# 3    XLC
# 4    XLC

# %%
# Load the third file of eleven downloaded from Yahoo Finance - (Remember to Change These)
XLE_pd = "Resources/XLE.csv"

# Read file and store into Pandas data frame
XLE = pd.read_csv(XLE_pd)
# Add a column with the ticker symbol
XLE['Ticker'] = 'XLE'

XLE.head()
# Out:
#        Date     Open      High      Low      Close  Adj Close  Volume Ticker
# 0  1/3/2000  27.3125  27.31250  26.3750  26.562500  18.118414  380300    XLE
# 1  1/4/2000  26.3125  26.31250  25.8750  26.062500  17.777370  722200    XLE
# 2  1/5/2000  26.1250  26.75000  26.0000  26.750000  18.246311  337800    XLE
# 3  1/6/2000  26.7500  27.84375  26.7500  27.781250  18.949726  133100    XLE
# 4  1/7/2000  27.6875  28.40625  27.6875  28.078119  19.152227  468000    XLE

# %%
# Load the fourth file of eleven downloaded from Yahoo Finance - (Remember to Change These)
XLF_pd = "Resources/XLF.csv"

# Read file and store into Pandas data frame
XLF = pd.read_csv(XLF_pd)
# Add a column with the ticker symbol
XLF['Ticker'] = 'XLF'

XLF.head()
# Out:
#        Date       Open       High        Low      Close  Adj Close   Volume  \
# 0  1/3/2000  19.267832  19.267832  18.455482  18.582453   9.546603  1185600
# 1  1/4/2000  18.176279  18.201624  17.605036  17.770105   9.129263   885700
# 2  1/5/2000  17.770105  17.960438  17.440048  17.630463   9.057525   717100
# 3  1/6/2000  17.681234  18.518929  17.681234  18.404711   9.455289   415800
# 4  1/7/2000  18.531681  18.734768  18.277822  18.709341   9.611789   468100
#
#   Ticker
# 0    XLF
# 1    XLF
# 2    XLF
# 3    XLF
# 4    XLF

# %%
# Load the fifth file of eleven downloaded from Yahoo Finance - (Remember to Change These)
XLI_pd = "Resources/XLI.csv"

# Read file and store into Pandas data frame
XLI = pd.read_csv(XLI_pd)
# Add a column with the ticker symbol
XLI['Ticker'] = 'XLI'

XLI.head()
# Out:
#          Date       Open       High      Low      Close  Adj Close  Volume  \
# 0  2000-01-03  29.484301  29.484301  28.6875  28.843700  20.171661   82800
# 1  2000-01-04  28.468700  28.609301  27.9375  28.046801  19.614346  146900
# 2  2000-01-05  28.000000  28.125000  27.7187  27.921801  19.526932  129200
# 3  2000-01-06  27.921801  28.375000  27.8125  28.296801  19.789181   54000
# 4  2000-01-07  28.625000  29.375000  28.6250  29.375000  20.543221   32900
#
#   Ticker
# 0    XLI
# 1    XLI
# 2    XLI
# 3    XLI
# 4    XLI

# %%
# Load the sixth file of eleven downloaded from Yahoo Finance - (Remember to Change These)
XLK_pd = "Resources/XLK.csv"

# Read file and store into Pandas data frame
XLK = pd.read_csv(XLK_pd)
# Add a column with the ticker symbol
XLK['Ticker'] = 'XLK'

XLK.head()
# Out:
#        Date    Open     High      Low    Close  Adj Close   Volume Ticker
# 0  1/3/2000  55.625  55.6250  53.5000  55.4375  43.764011   938100    XLK
# 1  1/4/2000  54.000  54.7500  52.3125  52.6250  41.543743   545500    XLK
# 2  1/5/2000  51.750  53.0625  50.1250  51.8437  40.926949  1906000    XLK
# 3  1/6/2000  51.250  52.0937  49.6250  50.1250  39.570152  1670000    XLK
# 4  1/7/2000  49.625  51.0000  49.1250  51.0000  40.260910   686000    XLK

# %%
# Load the seventh file of eleven downloaded from Yahoo Finance - (Remember to Change These)
XLP_pd = "Resources/XLP.csv"

# Read file and store into Pandas data frame
XLP = pd.read_csv(XLP_pd)
# Add a column with the ticker symbol
XLP['Ticker'] = 'XLP'

XLP.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  Volume  \
# 0  2000-01-03  23.125000  23.125000  22.468750  22.750000  14.516191  634300
# 1  2000-01-04  22.312500  22.656250  22.078119  22.109381  14.107430  172000
# 2  2000-01-05  22.265619  22.609381  22.093750  22.500000  14.356680  343600
# 3  2000-01-06  22.656250  23.000000  22.484381  22.921881  14.625863  420800
# 4  2000-01-07  23.328119  24.421881  23.265619  24.375000  15.553056  337100
#
#   Ticker
# 0    XLP
# 1    XLP
# 2    XLP
# 3    XLP
# 4    XLP

# %%
# Load the eighth file of eleven downloaded from Yahoo Finance - (Remember to Change These)
XLRE_pd = "Resources/XLRE.csv"

# Read file and store into Pandas data frame
XLRE = pd.read_csv(XLRE_pd)
# Add a column with the ticker symbol
XLRE['Ticker'] = 'XLRE'

XLRE.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  Volume  \
# 0   10/8/2015  30.010000  30.209999  30.010000  30.209999  26.390863    2000
# 1   10/9/2015  30.200001  30.200001  30.059999  30.160000  26.347187    4300
# 2  10/12/2015  30.420000  30.420000  30.270000  30.350000  26.513168    2300
# 3  10/13/2015  30.160000  30.160000  30.160000  30.160000  26.347187     500
# 4  10/14/2015  30.160000  30.160000  30.160000  30.160000  26.347187       0
#
#   Ticker
# 0   XLRE
# 1   XLRE
# 2   XLRE
# 3   XLRE
# 4   XLRE

# %%
# Load the ninth file of eleven downloaded from Yahoo Finance - (Remember to Change These)
XLU_pd = "Resources/XLU.csv"

# Read file and store into Pandas data frame
XLU = pd.read_csv(XLU_pd)
# Add a column with the ticker symbol
XLU['Ticker'] = 'XLU'

XLU.head()
# Out:
#        Date       Open       High        Low      Close  Adj Close  Volume  \
# 0  1/3/2000  28.937500  28.937500  27.218700  27.453100  13.603063  176700
# 1  1/4/2000  27.468700  27.468700  26.625000  26.625000  13.192731   93500
# 2  1/5/2000  27.218700  27.421801  26.859301  27.296801  13.525613  273400
# 3  1/6/2000  27.250000  27.250000  26.937500  27.250000  13.502423   34500
# 4  1/7/2000  27.296801  27.484301  27.171801  27.484301  13.618518   46200
#
#   Ticker
# 0    XLU
# 1    XLU
# 2    XLU
# 3    XLU
# 4    XLU

# %%
# Load the tenth file of eleven downloaded from Yahoo Finance - (Remember to Change These)
XLV_pd = "Resources/XLV.csv"

# Read file and store into Pandas data frame
XLV = pd.read_csv(XLV_pd)
# Add a column with the ticker symbol
XLV['Ticker'] = 'XLV'

XLV.head()
# Out:
#        Date     Open       High        Low      Close  Adj Close  Volume  \
# 0  1/3/2000  31.0000  31.000000  30.062500  30.296801  22.952749  246700
# 1  1/4/2000  30.1875  30.203100  29.531200  29.609301  22.431904   35300
# 2  1/5/2000  29.7812  29.781200  29.218700  29.343700  22.230686  137600
# 3  1/6/2000  29.3125  29.562500  29.156200  29.437500  22.301754   50000
# 4  1/7/2000  29.4687  29.796801  29.359301  29.796801  22.573957   22100
#
#   Ticker
# 0    XLV
# 1    XLV
# 2    XLV
# 3    XLV
# 4    XLV

# %%
# Load the twelfth file of eleven downloaded from Yahoo Finance - (Remember to Change These)
XLY_pd = "Resources/XLY.csv"

# Read file and store into Pandas data frame
XLY = pd.read_csv(XLY_pd)
# Add a column with the ticker symbol
XLY['Ticker'] = 'XLY'

XLY.head()
# Out:
#        Date       Open      High        Low      Close  Adj Close  Volume  \
# 0  1/3/2000  31.000000  31.00000  29.859381  30.125000  23.681404  212900
# 1  1/4/2000  29.687500  29.81250  29.031250  29.218750  22.968992  177200
# 2  1/5/2000  29.343750  29.34375  28.718750  28.859381  22.686501  124600
# 3  1/6/2000  29.046881  29.40625  29.000000  29.187500  22.944439  135800
# 4  1/7/2000  29.500000  30.56250  29.500000  30.562500  24.025324   70000
#
#   Ticker
# 0    XLY
# 1    XLY
# 2    XLY
# 3    XLY
# 4    XLY

# %%
# Put all the dataframes together 
sector_tickers = XLB.append([XLC, XLE, XLF, XLI, XLK, XLP, XLRE, XLU, XLV, XLY])
#sector_tickers_pd = pd.DataFrame(sector_tickers)

# Change the date column format to dd/mm/yyyy
#sector_tickers_pd['Date'] = sector_tickers_pd['Date'].dt.strftime('%m/%d/%Y')

#sector_tickers(['Date'],errors = 'coerce',format = '%Y-%m-%d').dt.strftime("%Y%m")
#sector_tickers_pd['Date'] = sector_tickers(['Date'] ,errors = 'coerce',format = '%Y-%m-%d').dt.strftime("%Y%m")

sector_tickers
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0      1/3/2000   26.671881   26.687500   25.937500   25.968750   16.565908
# 1      1/4/2000   26.000000   26.046881   25.609381   25.718750   16.406433
# 2      1/5/2000   26.015619   26.812500   25.750000   26.781250   17.084217
# 3      1/6/2000   26.796881   27.734381   26.781250   27.468750   17.522791
# 4      1/7/2000   27.750000   27.937500   27.453119   27.453119   17.512810
# 5     1/10/2000   27.703119   27.703119   27.140619   27.359381   17.453016
# 6     1/11/2000   27.140619   27.250000   26.828119   27.031250   17.243696
# 7     1/12/2000   26.609381   27.031250   26.609381   26.640619   16.994513
# 8     1/13/2000   26.890619   26.968750   26.625000   26.750000   17.064274
# 9     1/14/2000   26.515619   26.718750   26.437500   26.562500   16.944664
# 10    1/18/2000   26.218750   26.312500   25.687500   25.921881   16.536009
# ...

# %%
sector_tickers.to_csv('Resources/sector_tickers.csv')
