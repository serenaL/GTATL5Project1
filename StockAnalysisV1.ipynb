# %%
import numpy as np
from sklearn.svm import SVR
import matplotlib.pyplot as plt
import pandas as pd
from stockai import Stock
import datetime

# %%
#Specify path for csv files
path='/Users/serenaleung/Documents/GTATL201905DATA3/GTATL5Project1/XLB.csv'
XLB=pd.read_csv(path)
XLB.head()
# Out:
#        Date       Open       High        Low      Close  Adj Close   Volume
# 0  1/3/2000  26.671881  26.687500  25.937500  25.968750  16.565908   140500
# 1  1/4/2000  26.000000  26.046881  25.609381  25.718750  16.406433   258000
# 2  1/5/2000  26.015619  26.812500  25.750000  26.781250  17.084217   102700
# 3  1/6/2000  26.796881  27.734381  26.781250  27.468750  17.522791  1335000
# 4  1/7/2000  27.750000  27.937500  27.453119  27.453119  17.512810   620100

# %%
XLB["Ticker"]="XLB"

# %%
XLB.head()
# Out:
#        Date       Open       High        Low      Close  Adj Close   Volume  \
# 0  1/3/2000  26.671881  26.687500  25.937500  25.968750  16.565908   140500
# 1  1/4/2000  26.000000  26.046881  25.609381  25.718750  16.406433   258000
# 2  1/5/2000  26.015619  26.812500  25.750000  26.781250  17.084217   102700
# 3  1/6/2000  26.796881  27.734381  26.781250  27.468750  17.522791  1335000
# 4  1/7/2000  27.750000  27.937500  27.453119  27.453119  17.512810   620100
#
#   Ticker
# 0    XLB
# 1    XLB
# 2    XLB
# 3    XLB
# 4    XLB

# %%
XLB.count() #4197
# Out:
# Date         4917
# Open         4917
# High         4917
# Low          4917
# Close        4917
# Adj Close    4917
# Volume       4917
# dtype: int64

# %%
path='/Users/serenaleung/Documents/GTATL201905DATA3/GTATL5Project1/XLC.csv'
XLC=pd.read_csv(path)
XLC.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close   Volume
# 0  2018-06-19  49.700001  50.060001  49.580002  49.959999  49.457355    16600
# 1  2018-06-20  50.450001  50.889000  50.450001  50.580002  50.071121   190000
# 2  2018-06-21  50.770000  50.849998  50.200001  50.270000  49.764236   428700
# 3  2018-06-22  50.590000  50.610001  50.189999  50.490002  49.982029   181500
# 4  2018-06-25  50.230000  50.230000  49.014999  49.450001  48.952496  2509600

# %%
XLC["Ticker"]="XLC"

# %%
XLC.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close   Volume  \
# 0  2018-06-19  49.700001  50.060001  49.580002  49.959999  49.457355    16600
# 1  2018-06-20  50.450001  50.889000  50.450001  50.580002  50.071121   190000
# 2  2018-06-21  50.770000  50.849998  50.200001  50.270000  49.764236   428700
# 3  2018-06-22  50.590000  50.610001  50.189999  50.490002  49.982029   181500
# 4  2018-06-25  50.230000  50.230000  49.014999  49.450001  48.952496  2509600
#
#   Ticker
# 0    XLC
# 1    XLC
# 2    XLC
# 3    XLC
# 4    XLC

# %%
XLC.count() #273
# Out:
# Date         273
# Open         273
# High         273
# Low          273
# Close        273
# Adj Close    273
# Volume       273
# dtype: int64

# %%
path='/Users/serenaleung/Documents/GTATL201905DATA3/GTATL5Project1/XLE.csv'
XLE=pd.read_csv(path)
XLE.head()
# Out:
#        Date     Open      High      Low      Close  Adj Close  Volume
# 0  1/3/2000  27.3125  27.31250  26.3750  26.562500  18.118414  380300
# 1  1/4/2000  26.3125  26.31250  25.8750  26.062500  17.777370  722200
# 2  1/5/2000  26.1250  26.75000  26.0000  26.750000  18.246311  337800
# 3  1/6/2000  26.7500  27.84375  26.7500  27.781250  18.949726  133100
# 4  1/7/2000  27.6875  28.40625  27.6875  28.078119  19.152227  468000

# %%
XLE["Ticker"]="XLE"
XLE.head()
# Out:
#        Date     Open      High      Low      Close  Adj Close  Volume Ticker
# 0  1/3/2000  27.3125  27.31250  26.3750  26.562500  18.118414  380300    XLE
# 1  1/4/2000  26.3125  26.31250  25.8750  26.062500  17.777370  722200    XLE
# 2  1/5/2000  26.1250  26.75000  26.0000  26.750000  18.246311  337800    XLE
# 3  1/6/2000  26.7500  27.84375  26.7500  27.781250  18.949726  133100    XLE
# 4  1/7/2000  27.6875  28.40625  27.6875  28.078119  19.152227  468000    XLE

# %%
XLE.count() #4197
# Out:
# Date         4917
# Open         4917
# High         4917
# Low          4917
# Close        4917
# Adj Close    4917
# Volume       4917
# dtype: int64

# %%
path='/Users/serenaleung/Documents/GTATL201905DATA3/GTATL5Project1/XLF.csv'
XLF=pd.read_csv(path)
XLF.head()
# Out:
#        Date       Open       High        Low      Close  Adj Close   Volume
# 0  1/3/2000  19.267832  19.267832  18.455482  18.582453   9.546603  1185600
# 1  1/4/2000  18.176279  18.201624  17.605036  17.770105   9.129263   885700
# 2  1/5/2000  17.770105  17.960438  17.440048  17.630463   9.057525   717100
# 3  1/6/2000  17.681234  18.518929  17.681234  18.404711   9.455289   415800
# 4  1/7/2000  18.531681  18.734768  18.277822  18.709341   9.611789   468100

# %%
XLF["Ticker"]="XLF"
XLF.head()
# Out:
#        Date       Open       High        Low      Close  Adj Close   Volume  \
# 0  1/3/2000  19.267832  19.267832  18.455482  18.582453   9.546603  1185600
# 1  1/4/2000  18.176279  18.201624  17.605036  17.770105   9.129263   885700
# 2  1/5/2000  17.770105  17.960438  17.440048  17.630463   9.057525   717100
# 3  1/6/2000  17.681234  18.518929  17.681234  18.404711   9.455289   415800
# 4  1/7/2000  18.531681  18.734768  18.277822  18.709341   9.611789   468100
#
#   Ticker
# 0    XLF
# 1    XLF
# 2    XLF
# 3    XLF
# 4    XLF

# %%
XLF.count() #4197
# Out:
# Date         4917
# Open         4917
# High         4917
# Low          4917
# Close        4917
# Adj Close    4917
# Volume       4917
# dtype: int64

# %%
path='/Users/serenaleung/Documents/GTATL201905DATA3/GTATL5Project1/XLI.csv'
XLI=pd.read_csv(path)
XLI.head()
# Out:
#          Date       Open       High      Low      Close  Adj Close  Volume
# 0  2000-01-03  29.484301  29.484301  28.6875  28.843700  20.171661   82800
# 1  2000-01-04  28.468700  28.609301  27.9375  28.046801  19.614346  146900
# 2  2000-01-05  28.000000  28.125000  27.7187  27.921801  19.526932  129200
# 3  2000-01-06  27.921801  28.375000  27.8125  28.296801  19.789181   54000
# 4  2000-01-07  28.625000  29.375000  28.6250  29.375000  20.543221   32900

# %%
XLI["Ticker"]="XLI"
XLI.head()
# Out:
#          Date       Open       High      Low      Close  Adj Close  Volume  \
# 0  2000-01-03  29.484301  29.484301  28.6875  28.843700  20.171661   82800
# 1  2000-01-04  28.468700  28.609301  27.9375  28.046801  19.614346  146900
# 2  2000-01-05  28.000000  28.125000  27.7187  27.921801  19.526932  129200
# 3  2000-01-06  27.921801  28.375000  27.8125  28.296801  19.789181   54000
# 4  2000-01-07  28.625000  29.375000  28.6250  29.375000  20.543221   32900
#
#   Ticker
# 0    XLI
# 1    XLI
# 2    XLI
# 3    XLI
# 4    XLI

# %%
XLI.count() #4197
# Out:
# Date         4917
# Open         4917
# High         4917
# Low          4917
# Close        4917
# Adj Close    4917
# Volume       4917
# dtype: int64

# %%
path='/Users/serenaleung/Documents/GTATL201905DATA3/GTATL5Project1/XLK.csv'
XLK=pd.read_csv(path)
XLK.head()
# Out:
#        Date    Open     High      Low    Close  Adj Close   Volume
# 0  1/3/2000  55.625  55.6250  53.5000  55.4375  43.764011   938100
# 1  1/4/2000  54.000  54.7500  52.3125  52.6250  41.543743   545500
# 2  1/5/2000  51.750  53.0625  50.1250  51.8437  40.926949  1906000
# 3  1/6/2000  51.250  52.0937  49.6250  50.1250  39.570152  1670000
# 4  1/7/2000  49.625  51.0000  49.1250  51.0000  40.260910   686000

# %%
XLK["Ticker"]="XLK"
XLK.head()
# Out:
#        Date    Open     High      Low    Close  Adj Close   Volume Ticker
# 0  1/3/2000  55.625  55.6250  53.5000  55.4375  43.764011   938100    XLK
# 1  1/4/2000  54.000  54.7500  52.3125  52.6250  41.543743   545500    XLK
# 2  1/5/2000  51.750  53.0625  50.1250  51.8437  40.926949  1906000    XLK
# 3  1/6/2000  51.250  52.0937  49.6250  50.1250  39.570152  1670000    XLK
# 4  1/7/2000  49.625  51.0000  49.1250  51.0000  40.260910   686000    XLK

# %%
XLK.count()
# Out:
# Date         4917
# Open         4917
# High         4917
# Low          4917
# Close        4917
# Adj Close    4917
# Volume       4917
# dtype: int64

# %%
path='/Users/serenaleung/Documents/GTATL201905DATA3/GTATL5Project1/XLP.csv'
XLP=pd.read_csv(path)
XLP.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  Volume
# 0  2000-01-03  23.125000  23.125000  22.468750  22.750000  14.516191  634300
# 1  2000-01-04  22.312500  22.656250  22.078119  22.109381  14.107430  172000
# 2  2000-01-05  22.265619  22.609381  22.093750  22.500000  14.356680  343600
# 3  2000-01-06  22.656250  23.000000  22.484381  22.921881  14.625863  420800
# 4  2000-01-07  23.328119  24.421881  23.265619  24.375000  15.553056  337100

# %%
XLP["Ticker"]="XLP"
XLP.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  Volume  \
# 0  2000-01-03  23.125000  23.125000  22.468750  22.750000  14.516191  634300
# 1  2000-01-04  22.312500  22.656250  22.078119  22.109381  14.107430  172000
# 2  2000-01-05  22.265619  22.609381  22.093750  22.500000  14.356680  343600
# 3  2000-01-06  22.656250  23.000000  22.484381  22.921881  14.625863  420800
# 4  2000-01-07  23.328119  24.421881  23.265619  24.375000  15.553056  337100
#
#   Ticker
# 0    XLP
# 1    XLP
# 2    XLP
# 3    XLP
# 4    XLP

# %%
XLP.count()#4197
# Out:
# Date         4917
# Open         4917
# High         4917
# Low          4917
# Close        4917
# Adj Close    4917
# Volume       4917
# dtype: int64

# %%
path='/Users/serenaleung/Documents/GTATL201905DATA3/GTATL5Project1/XLRE.csv'
XLRE=pd.read_csv(path)
XLRE.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  Volume
# 0   10/8/2015  30.010000  30.209999  30.010000  30.209999  26.390863    2000
# 1   10/9/2015  30.200001  30.200001  30.059999  30.160000  26.347187    4300
# 2  10/12/2015  30.420000  30.420000  30.270000  30.350000  26.513168    2300
# 3  10/13/2015  30.160000  30.160000  30.160000  30.160000  26.347187     500
# 4  10/14/2015  30.160000  30.160000  30.160000  30.160000  26.347187       0

# %%
XLRE["Ticker"]="XLRE"
XLRE.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  Volume  \
# 0   10/8/2015  30.010000  30.209999  30.010000  30.209999  26.390863    2000
# 1   10/9/2015  30.200001  30.200001  30.059999  30.160000  26.347187    4300
# 2  10/12/2015  30.420000  30.420000  30.270000  30.350000  26.513168    2300
# 3  10/13/2015  30.160000  30.160000  30.160000  30.160000  26.347187     500
# 4  10/14/2015  30.160000  30.160000  30.160000  30.160000  26.347187       0
#
#   Ticker
# 0   XLRE
# 1   XLRE
# 2   XLRE
# 3   XLRE
# 4   XLRE

# %%
XLRE.count() #951
# Out:
# Date         951
# Open         951
# High         951
# Low          951
# Close        951
# Adj Close    951
# Volume       951
# dtype: int64

# %%
path='/Users/serenaleung/Documents/GTATL201905DATA3/GTATL5Project1/XLU.csv'
XLU=pd.read_csv(path)
XLU.head()
# Out:
#        Date       Open       High        Low      Close  Adj Close  Volume
# 0  1/3/2000  28.937500  28.937500  27.218700  27.453100  13.603063  176700
# 1  1/4/2000  27.468700  27.468700  26.625000  26.625000  13.192731   93500
# 2  1/5/2000  27.218700  27.421801  26.859301  27.296801  13.525613  273400
# 3  1/6/2000  27.250000  27.250000  26.937500  27.250000  13.502423   34500
# 4  1/7/2000  27.296801  27.484301  27.171801  27.484301  13.618518   46200

# %%
XLU["Ticker"]="XLU"
XLU.head()
# Out:
#        Date       Open       High        Low      Close  Adj Close  Volume  \
# 0  1/3/2000  28.937500  28.937500  27.218700  27.453100  13.603063  176700
# 1  1/4/2000  27.468700  27.468700  26.625000  26.625000  13.192731   93500
# 2  1/5/2000  27.218700  27.421801  26.859301  27.296801  13.525613  273400
# 3  1/6/2000  27.250000  27.250000  26.937500  27.250000  13.502423   34500
# 4  1/7/2000  27.296801  27.484301  27.171801  27.484301  13.618518   46200
#
#   Ticker
# 0    XLU
# 1    XLU
# 2    XLU
# 3    XLU
# 4    XLU

# %%
XLU.count()#4197
# Out:
# Date         4917
# Open         4917
# High         4917
# Low          4917
# Close        4917
# Adj Close    4917
# Volume       4917
# dtype: int64

# %%
path='/Users/serenaleung/Documents/GTATL201905DATA3/GTATL5Project1/XLV.csv'
XLV=pd.read_csv(path)
XLV.head()
# Out:
#        Date     Open       High        Low      Close  Adj Close  Volume
# 0  1/3/2000  31.0000  31.000000  30.062500  30.296801  22.952749  246700
# 1  1/4/2000  30.1875  30.203100  29.531200  29.609301  22.431904   35300
# 2  1/5/2000  29.7812  29.781200  29.218700  29.343700  22.230686  137600
# 3  1/6/2000  29.3125  29.562500  29.156200  29.437500  22.301754   50000
# 4  1/7/2000  29.4687  29.796801  29.359301  29.796801  22.573957   22100

# %%
XLV["Ticker"]="XLV"
XLV.head()
# Out:
#        Date     Open       High        Low      Close  Adj Close  Volume  \
# 0  1/3/2000  31.0000  31.000000  30.062500  30.296801  22.952749  246700
# 1  1/4/2000  30.1875  30.203100  29.531200  29.609301  22.431904   35300
# 2  1/5/2000  29.7812  29.781200  29.218700  29.343700  22.230686  137600
# 3  1/6/2000  29.3125  29.562500  29.156200  29.437500  22.301754   50000
# 4  1/7/2000  29.4687  29.796801  29.359301  29.796801  22.573957   22100
#
#   Ticker
# 0    XLV
# 1    XLV
# 2    XLV
# 3    XLV
# 4    XLV

# %%
XLV.count() #4917
# Out:
# Date         4917
# Open         4917
# High         4917
# Low          4917
# Close        4917
# Adj Close    4917
# Volume       4917
# dtype: int64

# %%
path='/Users/serenaleung/Documents/GTATL201905DATA3/GTATL5Project1/XLY.csv'
XLY=pd.read_csv(path)
XLY.head()
# Out:
#        Date       Open      High        Low      Close  Adj Close  Volume
# 0  1/3/2000  31.000000  31.00000  29.859381  30.125000  23.681404  212900
# 1  1/4/2000  29.687500  29.81250  29.031250  29.218750  22.968992  177200
# 2  1/5/2000  29.343750  29.34375  28.718750  28.859381  22.686501  124600
# 3  1/6/2000  29.046881  29.40625  29.000000  29.187500  22.944439  135800
# 4  1/7/2000  29.500000  30.56250  29.500000  30.562500  24.025324   70000

# %%
XLY["Ticker"]="XLY"
XLY.head()
# Out:
#        Date       Open      High        Low      Close  Adj Close  Volume  \
# 0  1/3/2000  31.000000  31.00000  29.859381  30.125000  23.681404  212900
# 1  1/4/2000  29.687500  29.81250  29.031250  29.218750  22.968992  177200
# 2  1/5/2000  29.343750  29.34375  28.718750  28.859381  22.686501  124600
# 3  1/6/2000  29.046881  29.40625  29.000000  29.187500  22.944439  135800
# 4  1/7/2000  29.500000  30.56250  29.500000  30.562500  24.025324   70000
#
#   Ticker
# 0    XLY
# 1    XLY
# 2    XLY
# 3    XLY
# 4    XLY

# %%
XLY.count()#4917
# Out:
# Date         4917
# Open         4917
# High         4917
# Low          4917
# Close        4917
# Adj Close    4917
# Volume       4917
# dtype: int64

# %%
#combine all datasets
ElevenSectors=pd.concat([XLB, XLC, XLE, XLF, XLI, XLK, XLP, XLRE, XLU, XLV, XLY] )

# %%
#make a list of files to import

# filelist=['XLC','XLE','XLF','XLI','XLK','XLP','XLRE','XLU','XLV','XLY']
# files=[]
# filecount=1
# for filename in filelist:
#     path='/Users/serenaleung/Documents/GTATL201905DATA3/GTATL5Project1/'+ filename +'.csv'
#     data=pd.read_csv(path)
#     XLB.append(data)
    
#df.append(file)

# %%
#read in holidays data file
StockHoliday=pd.read_csv('/Users/serenaleung/Documents/GTATL201905DATA3/GTATL5Project1/Stock HolidaysPlusDayBefore.csv')

# %%
StockHoliday.head(25)
# Out:
#    HolidayDate      Date                              Holiday  Num  \
# 0     12/31/10  12/30/10                       New Year's Day  1.0
# 1      1/17/11   1/16/11  Birthday of Martin Luther King, Jr.  2.0
# 2      2/21/11   2/20/11                      President's Day  2.0
# 3      4/22/11   4/21/11                          Good Friday  6.0
# 4      5/30/11   5/29/11                         Memorial Day  2.0
# 5       7/4/11    7/3/11                     Independence Day  2.0
# 6       9/5/11    9/4/11                            Labor Day  2.0
# 7     11/24/11  11/23/11                     Thanksgiving Day  5.0
# 8     12/26/11  12/25/11                        Christmas Day  2.0
# 9       1/2/12    1/1/12                       New Year's Day  2.0
# 10     1/16/12   1/15/12  Birthday of Martin Luther King, Jr.  2.0
# 11     2/20/12   2/19/12                      President's Day  2.0
# 12      4/6/12    4/5/12                          Good Friday  6.0
# ...

# %%
ElevSectHoliday=pd.merge(ElevenSectors, StockHoliday, how="left", on="Date")

# %%
ElevSectHoliday.fillna(0)
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0       1/3/2000   26.671881   26.687500   25.937500   25.968750   16.565908
# 1       1/4/2000   26.000000   26.046881   25.609381   25.718750   16.406433
# 2       1/5/2000   26.015619   26.812500   25.750000   26.781250   17.084217
# 3       1/6/2000   26.796881   27.734381   26.781250   27.468750   17.522791
# 4       1/7/2000   27.750000   27.937500   27.453119   27.453119   17.512810
# ...          ...         ...         ...         ...         ...         ...
# 45472  7/15/2019  124.349998  124.540001  123.849998  124.480003  124.480003
# 45473  7/16/2019  124.300003  124.599998  123.930000  124.320000  124.320000
# 45474  7/17/2019  124.169998  124.349998  123.129997  123.129997  123.129997
# 45475  7/18/2019  122.879997  123.209999  122.150002  122.970001  122.970001
# 45476  7/19/2019  123.349998  123.519997  122.089996  122.160004  122.160004
#
# ...

# %%
ElevSectHoliday.Holiday.unique()
# Out:
# array([nan], dtype=object)

# %%
ElevSectHoliday['Weekday']=datetime.datetime.weekday(ElevSectHoliday["Date"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/p1/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2889             try:
# -> 2890                 return self._engine.get_loc(key)
#    2891             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-159-a74720bf55a3> in <module>
# ...

# %%
ElevSectHoliday
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0       1/3/2000   26.671881   26.687500   25.937500   25.968750   16.565908
# 1       1/4/2000   26.000000   26.046881   25.609381   25.718750   16.406433
# 2       1/5/2000   26.015619   26.812500   25.750000   26.781250   17.084217
# 3       1/6/2000   26.796881   27.734381   26.781250   27.468750   17.522791
# 4       1/7/2000   27.750000   27.937500   27.453119   27.453119   17.512810
# ...          ...         ...         ...         ...         ...         ...
# 45472  7/15/2019  124.349998  124.540001  123.849998  124.480003  124.480003
# 45473  7/16/2019  124.300003  124.599998  123.930000  124.320000  124.320000
# 45474  7/17/2019  124.169998  124.349998  123.129997  123.129997  123.129997
# 45475  7/18/2019  122.879997  123.209999  122.150002  122.970001  122.970001
# 45476  7/19/2019  123.349998  123.519997  122.089996  122.160004  122.160004
#
# ...

# %%
ElevSectHoliday.describe()
# Out:
#                Open          High           Low         Close     Adj Close  \
# count  45477.000000  45477.000000  45477.000000  45477.000000  45477.000000
# mean      38.664595     38.937177     38.365989     38.662164     32.623983
# std       19.182105     19.284609     19.073686     19.185763     19.894087
# min        4.914703      5.239643      4.776604      5.020308      3.167966
# 25%       25.309999     25.510000     25.080000     25.299999     18.195387
# 50%       32.000000     32.189999     31.760000     31.980000     26.143448
# 75%       49.090000     49.410000     48.759998     49.110001     43.845840
# max      124.349998    124.599998    123.930000    124.480003    124.480003
#
#              Volume  Unnamed: 0  Weekday
# count  4.547700e+04   72.000000  45477.0
# mean   1.254499e+07  108.333333      2.0
# std    3.037678e+07   67.521723      0.0
# min    0.000000e+00    0.000000      2.0
# 25%    9.803000e+05   48.000000      2.0
# ...

# %%
SectHolGrp=ElevSectHoliday.groupby(['Ticker'])

# %%
SectHolGrp.boxplot("Close",figsize=(15,15))
plt.

# %%
SectHolGrp.describe()
# Out:
#           Open                                                         \
#          count       mean        std        min        25%        50%
# Ticker
# XLB     4917.0  36.182825  11.812200  16.730000  26.090000  35.240002
# XLC      273.0  47.413883   2.521045  39.270000  45.919998  47.950001
# XLE     4917.0  57.019836  20.296139  19.400000  35.720001  61.590000
# XLF     4917.0  19.917396   5.690442   4.914703  16.173841  20.138100
# XLI     4917.0  40.105326  16.069179  15.480000  28.490000  34.750000
# XLK     4917.0  32.699791  16.076803  11.500000  21.040001  25.990000
# XLP     4917.0  33.695405  12.218835  17.850000  23.740000  27.660000
# XLRE     951.0  32.357447   1.897094  27.219999  31.051499  32.119999
# XLU     4917.0  36.088808   9.890606  15.240000  29.030001  34.234299
# XLV     4917.0  44.379581  20.886009  21.000000  29.500000  32.700001
# XLY     4917.0  48.626478  26.670728  16.049999  29.370001  35.290001
#
# ...

# %%
#plot by sector



SectHolGrp.plot("Date","Close", linewidth=0, marker="o", ms=3, alpha=.2, color="darkblue", subplots=True, sharex=True, sharey=True, figsize=(15,5))
#SectHolGrp.plot("Holiday", linewidth=0, marker="^", color="red")
# Out:
# Ticker
# XLB     [AxesSubplot(0.125,0.2;0.775x0.68)]
# XLC     [AxesSubplot(0.125,0.2;0.775x0.68)]
# XLE     [AxesSubplot(0.125,0.2;0.775x0.68)]
# XLF     [AxesSubplot(0.125,0.2;0.775x0.68)]
# XLI     [AxesSubplot(0.125,0.2;0.775x0.68)]
# XLK     [AxesSubplot(0.125,0.2;0.775x0.68)]
# XLP     [AxesSubplot(0.125,0.2;0.775x0.68)]
# XLRE    [AxesSubplot(0.125,0.2;0.775x0.68)]
# XLU     [AxesSubplot(0.125,0.2;0.775x0.68)]
# XLV     [AxesSubplot(0.125,0.2;0.775x0.68)]
# XLY     [AxesSubplot(0.125,0.2;0.775x0.68)]
# dtype: object

# %%
fig, ax1 = plt.subplots(4,4,sharex=True, sharey=True,figsize=(20,15))
#ax2 = ax1.twinx()
ax1.plot(SectHolGrp["Close"])
# use unstack()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-129-80024e37bcfe> in <module>
#       1 fig, ax1 = plt.subplots(4,4,sharex=True, sharey=True,figsize=(20,15))
#       2 #ax2 = ax1.twinx()
# ----> 3 ax1.plot(SectHolGrp["Close"])
#       4 # use unstack()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'plot'

# %%
ElevSectHoliday["Holiday"].unique()
# Out:
# array([nan, '(World Trade Center Day)', 'Good Friday', "New Year's Day"],
#       dtype=object)
